# %%
import numpy as np

from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
import pickle
import matplotlib.pyplot as plt
from matplotlib import ticker
# import torch
# from dqn import MolDQN
# from rdkit.Chem import QED
# from beautifultable import BeautifulTable, BTRowCollection
# from prettytable import PrettyTable

import pandas as pd
# import pickle
# import joblib

from rdkit import RDConfig
import os
import sys
sys.path.append(os.path.join(RDConfig.RDContribDir, 'SA_Score'))
import sascorer

# from rdkit.DataManip.Metric import GetTanimotoDistMat
# from rdkit.DataManip.Metric import GetTanimotoSimMat

IPythonConsole.ipython_useSVG=True
def movingaverage(interval, window_size):
    window = np.ones(int(window_size))/float(window_size)
    return np.convolve(interval, window, 'valid')

# def load_all_ranks(path, ranks, data):
#     data = np.load('./Experiments/trial_{}_rank_{}_{}.npy'.format(trial, ranks[0], data))
#     for r in ranks[1:]:
#         data

# %%
reward_list_0 = np.load('./Experiments/trial_224_rewards_mol_1.npy')
reward_list_ma_0 = movingaverage(reward_list_0, 1)
plt.figure(facecolor='white')
plt.plot(reward_list_ma_0)
# init_reward = 1.1120
with open('./Experiments/initial_reward_trial_224_mol_1.pickle', 'rb') as f:
    init_reward = pickle.load(f)
init_l = plt.axhline(init_reward, color='orange')
plt.legend(handles=[init_l],labels=['Initial Reward'],loc='best')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.ylim((0, 2.25))
epsilon_list = 0.999**(np.arange(len(reward_list_ma_0)))
ax2 = plt.twinx()
ax2.set_ylabel('Epsilon')
ax2.plot(epsilon_list, color='r')
ax2.tick_params(axis='y', labelcolor='r')
plt.title('BDE Weight: 0.8, IP Weight: 0.2')
plt.savefig("./reward_224_a.png", dpi = 500)

# %%
reward_list_0 = np.load('./Experiments/trial_225_rewards_mol_0.npy')
reward_list_ma_0 = movingaverage(reward_list_0, 1)
plt.figure(facecolor='white')
plt.plot(reward_list_ma_0)
# init_reward = 1.1120
with open('./Experiments/initial_reward_trial_225_mol_0.pickle', 'rb') as f:
    init_reward = pickle.load(f)
init_l = plt.axhline(init_reward, color='orange')
plt.legend(handles=[init_l],labels=['initial reward'],loc='best')
plt.xlabel('Episode')
plt.ylabel('BDE + IP Reward')
plt.ylim((0, 2.25))
epsilon_list = 0.999**(np.arange(len(reward_list_ma_0)))
ax2 = plt.twinx()
ax2.set_ylabel('Epsilon')
ax2.plot(epsilon_list, color='r')
ax2.tick_params(axis='y', labelcolor='r')
plt.title('Moving average of 20 episodes (BDE + IP, MT, 12 mols)')
plt.savefig("./reward_225.png")

# %%
reward_list_0 = np.load('./Experiments/trial_226_rewards_mol_4.npy')
reward_list_ma_0 = movingaverage(reward_list_0, 1)
plt.figure(facecolor='white')
plt.plot(reward_list_ma_0)
# init_reward = 1.1120
with open('./Experiments/initial_reward_trial_226_mol_4.pickle', 'rb') as f:
    init_reward = pickle.load(f)
init_l = plt.axhline(init_reward, color='orange')
plt.legend(handles=[init_l],labels=['Initial Reward'],loc='best')
plt.xlabel('Episode')
plt.ylabel('Final Reward (BDE + IP + RRAB)')
plt.ylim((0, 2.25))
epsilon_list = 0.999**(np.arange(len(reward_list_ma_0)))
ax2 = plt.twinx()
ax2.set_ylabel('Epsilon')
ax2.plot(epsilon_list, color='r')
ax2.tick_params(axis='y', labelcolor='r')
plt.title('BDE Weight: 0.5, IP Weight: 0.5')
plt.savefig("./reward_226_b.png")

# %%
reward_list_0 = np.load('./Experiments/trial_227_rewards_mol_0.npy')
reward_list_ma_0 = movingaverage(reward_list_0, 1)
plt.figure(facecolor='white')
plt.plot(reward_list_ma_0)
# init_reward = 1.1120
with open('./Experiments/initial_reward_trial_227_mol_0.pickle', 'rb') as f:
    init_reward = pickle.load(f)
init_l = plt.axhline(init_reward, color='orange')
plt.legend(handles=[init_l],labels=['Initial Reward'],loc='best')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.ylim((0, 2.25))
epsilon_list = 0.999**(np.arange(len(reward_list_ma_0)))
ax2 = plt.twinx()
ax2.set_ylabel('Epsilon')
ax2.plot(epsilon_list, color='r')
ax2.tick_params(axis='y', labelcolor='r')
plt.title('BDE Weight: 0.1, IP Weight: 0.9')
plt.savefig("./reward_227_c.png", dpi = 500)

# %%
reward_list_0 = np.load('./Experiments/trial_32_rewards_mol_0.npy')
reward_list_0 = np.append(reward_list_0, np.load('./Experiments/trial_33_rewards_mol_0.npy'))
reward_list_0 = np.append(reward_list_0, np.load('./Experiments/trial_34_rewards_mol_0.npy'))
# np.shape(reward_list_0)

reward_list_ma_0 = movingaverage(reward_list_0, 1)
plt.figure(facecolor='white')
plt.plot(reward_list_ma_0)
# init_reward = 1.1120
with open('./Experiments/initial_reward_trial_32_mol_0.pickle', 'rb') as f:
    init_reward = pickle.load(f)
init_l = plt.axhline(init_reward, color='orange')
plt.legend(handles=[init_l],labels=['Initial Reward'],loc='best')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.ylim((0, 2.25))
epsilon_list = 0.999**(np.arange(len(reward_list_ma_0)))
ax2 = plt.twinx()
ax2.set_ylabel('Epsilon')
ax2.plot(epsilon_list, color='r')
ax2.tick_params(axis='y', labelcolor='r')
plt.title('BDE Weight: 0.8, IP Weight: 0.2')
plt.savefig("./reward_32-34.png", dpi = 500)

# %%
trial = 438
rank = 0

reward_list_0 = np.load('./Experiments/trial_{}_rewards_rank_{}.npy'.format(trial, rank))
# print(reward_list_0[:,0].shape)
episodes = reward_list_0[:,0].shape
reward_list_0 = reward_list_0[:,0]
reward_list_ma_0 = movingaverage(reward_list_0, 1)
plt.figure(facecolor='white')
plt.plot(reward_list_ma_0)
# init_reward = 1.1120
with open('./Experiments/initial_reward_trial_{}_rank_{}.pickle'.format(trial, rank), 'rb') as f:
    init_reward = pickle.load(f)
    print(init_reward)
init_l = plt.axhline(init_reward[rank], color='orange')
plt.legend(handles=[init_l],labels=['Initial Reward'],loc='best')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.ylim((0, 2.25))
# plt.ylim((0, 30))
epsilon_list = 0.996**(np.arange(len(reward_list_ma_0)))
ax2 = plt.twinx()
ax2.set_ylabel('Epsilon')
ax2.plot(epsilon_list, color='r')
ax2.tick_params(axis='y', labelcolor='r')
plt.title('BDE Weight: 0.8, IP Weight: 0.2, Episodes: {}'.format(episodes[0]))
# plt.savefig("./Results/reward_trial_{}_rank_{}.png".format(trial, rank), dpi = 500)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       1 trial = 5735
#       2 rank = 0
# ----> 4 reward_list_0 = np.load('./Experiments/trial_{}_rewards_rank_{}.npy'.format(trial, rank))
#       5 # print(reward_list_0[:,0].shape)
#       6 episodes = reward_list_0[:,0].shape
#
# File ~/anaconda3/envs/rdkit/lib/python3.9/site-packages/numpy/lib/npyio.py:417, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415     own_fid = False
#     416 else:
# --> 417     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418     own_fid = True
#     420 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './Experiments/trial_5735_rewards_rank_0.npy'

# %%
trial = 56
ranks = range(1)

memory = [np.load('./Experiments/trial_{}_rank_{}_memory.npy'.format(trial, rank)) for rank in ranks]
for mi in memory[1:]:
    memory[0] += mi
memory = memory[0] / (1024 * 1024 * 1024)

t2 = 55
r2 = range(1)
memory2 = [np.load('./Experiments/trial_{}_rank_{}_memory.npy'.format(t2, r)) for r in r2]
for mi in memory2[1:]:
    memory2[0] += mi
memory2 = memory2[0] / (1024 * 1024 * 1024)

memory_ct = np.load('./cenv_test_memory.npy')
memory_ct = memory_ct / (1024 * 1024 * 1024)
print(memory_ct)

memory_ctf = np.load('./cenv_test_memory_f.npy')
memory_ctf = memory_ctf / (1024 * 1024 * 1024)
print(memory_ctf)

hit_rate = [np.load('./Experiments/trial_{}_rank_{}_episode_lru_cache_hit_rate.npy'.format(trial, rank)) for rank in ranks]
for hi in hit_rate[1:]:
    hit_rate[0] += hi
hit_rate = hit_rate[0] / len(ranks)

# episode_time = np.load('./Experiments/trial_{}_rank_{}_episode_time.npy'.format(trial, 0))
# epsilon_list = 0.985**(np.arange(len(memory)))

hit_rate = movingaverage(hit_rate, 20)
episode_time = movingaverage(episode_time, 20)

print(memory.shape)
print(hit_rate.shape)
print(episode_time.shape)
episodes = memory.shape

fig, ax = plt.subplots()
# fig.subplots_adjust(right=0.75)

# twin1 = ax.twinx()
# twin2 = ax.twinx()

# Offset the right spine of twin2.  The ticks and label have already been
# placed on the right by twinx above.
# twin2.spines.right.set_position(("axes", 1.2))

p1, = ax.plot(memory, "b-", label=f"{trial}")
p12, = ax.plot(memory2, "r-", label=f"{t2}")
p1ct, = ax.plot(memory_ct, "g-", label="cenv")
p1ct, = ax.plot(memory_ctf, "yellow", label="cenv_f")

# p2, = twin1.plot(hit_rate, "orange", label="BDE Cache Hit Rate")
# p3, = twin1.plot(epsilon_list, "r-", label="Epsilon")
# p4, = twin2.plot(episode_time, "g-", label="Episode Time")

ax.set_xlabel("Episode")
ax.set_ylabel("Memory Usage (GB)")
# twin1.set_ylabel("BDE Cache Hit Rate (%)")
# twin2.set_ylabel("Episode Time (sec)")

ax.yaxis.label.set_color(p1.get_color())
# twin1.yaxis.label.set_color(p2.get_color())
# twin2.yaxis.label.set_color(p4.get_color())
# ax.set_ylim(0, 256)
# twin1.set_ylim(0,1.1)
# twin2.set_ylim(0, 10)

# twin1.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1,decimals=1))

tkw = dict(size=4, width=1.5)
ax.tick_params(axis='y', colors=p1.get_color(), **tkw)
# twin1.tick_params(axis='y', colors=p2.get_color(), **tkw)
# twin2.tick_params(axis='y', colors=p4.get_color(), **tkw)
ax.tick_params(axis='x', **tkw)

# lgd = plt.legend(handles=[p1, p12], loc='right', bbox_to_anchor=(1.0, -0.4))
lgd = plt.legend(handles=[p1, p12], loc='best')
plt.title('Memory usage, Cache Hit Rate and Episode Time')
plt.savefig("./Results/trial_{}_Memory_Cache_Time.png".format(trial), dpi = 500, bbox_extra_artists=(lgd, ))
plt.show()
# Out:
# [0.06427765 0.06478119 0.06478119 ... 0.82954407 0.82954407 0.82954407]
# [0.06206131 0.06231308 0.06231308 ... 0.06789398 0.06789398 0.06789398]
# (8000,)
# (7981,)
# (7924,)

# %%
trial = 439
rank = 10

reward_list_0 = np.load('./Experiments/trial_{}_rank_{}_rewards.npy'.format(trial, rank))
# print(reward_list_0[:,0].shape)
episodes = reward_list_0[:,0].shape
reward_list_0 = reward_list_0[:,0]
reward_list_ma_0 = movingaverage(reward_list_0, 1)
plt.figure(facecolor='white')
plt.plot(reward_list_ma_0)
with open('./Experiments/initial_reward_trial_{}_rank_{}.pickle'.format(trial, rank), 'rb') as f:
    init_reward = pickle.load(f)
    print(init_reward)
init_l = plt.axhline(init_reward[0], color='orange')
plt.legend(handles=[init_l],labels=['Initial Reward'],loc='best')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.ylim((0, 2.25))
# plt.ylim((0, 30))
epsilon_list = 0.985**(np.arange(len(reward_list_ma_0)))
ax2 = plt.twinx()
ax2.set_ylabel('Epsilon')
ax2.plot(epsilon_list, color='r')
ax2.tick_params(axis='y', labelcolor='r')
# plt.title('BDE Weight: 0.8, IP Weight: 0.2, Trial: {}'.format(trial))
plt.title('Trial: {}'.format(trial))
plt.savefig("./Results/reward_trial_{}_rank_{}.png".format(trial, rank), dpi = 500)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [63], in <cell line: 11>()
#       9 plt.figure(facecolor='white')
#      10 plt.plot(reward_list_ma_0)
# ---> 11 with open('./Experiments/initial_reward_trial_{}_rank_{}.pickle'.format(trial, rank), 'rb') as f:
#      12     init_reward = pickle.load(f)
#      13     print(init_reward)
#
# FileNotFoundError: [Errno 2] No such file or directory: './Experiments/initial_reward_trial_451_rank_10.pickle'

# %%
trial = 456
rank = 10

reward_list_0 = np.load('./Experiments/trial_{}_rewards_rank_{}.npy'.format(trial, rank))
# print(reward_list_0[:,0].shape)
episodes = reward_list_0[:,0].shape
reward_list_0 = reward_list_0[:,0]
reward_list_ma_0 = movingaverage(reward_list_0, 5)
plt.figure(facecolor='white')
plt.plot(reward_list_ma_0)
with open('./Experiments/initial_reward_trial_{}_rank_{}.pickle'.format(trial, rank), 'rb') as f:
    init_reward = pickle.load(f)
    print(init_reward)
init_l = plt.axhline(init_reward[0], color='orange')
plt.legend(handles=[init_l],labels=['Initial Reward'],loc='best')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.ylim((0, 2.25))
# plt.ylim((0, 30))
epsilon_list = 0.985**(np.arange(len(reward_list_ma_0)))
ax2 = plt.twinx()
ax2.set_ylabel('Epsilon')
ax2.plot(epsilon_list, color='r')
ax2.tick_params(axis='y', labelcolor='r')
# plt.title('BDE Weight: 0.8, IP Weight: 0.2, Trial: {}'.format(trial))
plt.title('Trial: {}'.format(trial))
plt.savefig("./Results/reward_trial_{}_rank_{}.png".format(trial, rank), dpi = 500)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <cell line: 4>()
#       1 trial = 456
#       2 rank = 10
# ----> 4 reward_list_0 = np.load('./Experiments/trial_{}_rewards_rank_{}.npy'.format(trial, rank))
#       5 # print(reward_list_0[:,0].shape)
#       6 episodes = reward_list_0[:,0].shape
#
# File ~/anaconda3/envs/rdkit/lib/python3.9/site-packages/numpy/lib/npyio.py:417, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415     own_fid = False
#     416 else:
# --> 417     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418     own_fid = True
#     420 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './Experiments/trial_456_rewards_rank_10.npy'

# %%
trials = range(5735, 5734)
rank = 0
for trial in trials:
    reward_list_0 = np.load('./Experiments/trial_{}_rank_{}_rewards.npy'.format(trial, rank))
    # print(reward_list_0[:,0].shape)
    episodes = reward_list_0[:,0].shape
    reward_list_0 = reward_list_0[:,0]
    reward_list_ma_0 = movingaverage(reward_list_0, 1)
    plt.figure(facecolor='white')
    plt.plot(reward_list_ma_0)
    with open('./Experiments/trial_{}_rank_{}_initial_reward.pickle'.format(trial, rank), 'rb') as f:
        init_reward = pickle.load(f)
#         print(init_reward)
    init_l = plt.axhline(init_reward[0], color='orange')
    plt.legend(handles=[init_l],labels=['Initial Reward'],loc='best')
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.ylim((0, 2.25))
    # plt.ylim((0, 30))
    epsilon_list = 0.97**(np.arange(len(reward_list_ma_0)))
    ax2 = plt.twinx()
    ax2.set_ylabel('Epsilon')
    ax2.plot(epsilon_list, color='r')
    ax2.tick_params(axis='y', labelcolor='r')
    # plt.title('BDE Weight: 0.8, IP Weight: 0.2, Trial: {}'.format(trial))
    plt.title('Trial: {}'.format(trial))
    plt.savefig("./Results/reward_trial_{}_rank_{}.png".format(trial, rank), dpi = 500)

# %%
trial = 55731
rank = 0
reward_list_0 = np.load('./Experiments/trial_{}_rank_{}_rewards.npy'.format(trial, rank))
# print(reward_list_0[:,0].shape)
episodes = reward_list_0[:,0].shape
reward_list_0 = reward_list_0[:,0]
reward_list_ma_0 = movingaverage(reward_list_0, 1)
plt.figure(facecolor='white')
plt.plot(reward_list_ma_0)
with open('./Experiments/trial_{}_rank_{}_initial_reward.pickle'.format(trial, rank), 'rb') as f:
    init_reward = pickle.load(f)
#         print(init_reward)
init_l = plt.axhline(init_reward[0], color='orange')
plt.legend(handles=[init_l],labels=['Initial Reward'],loc='best')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.ylim((0, 2.25))
# plt.ylim((0, 30))
epsilon_list = 0.985**(np.arange(len(reward_list_ma_0)))
ax2 = plt.twinx()
ax2.set_ylabel('Epsilon')
ax2.plot(epsilon_list, color='r')
ax2.tick_params(axis='y', labelcolor='r')
# plt.title('BDE Weight: 0.8, IP Weight: 0.2, Trial: {}'.format(trial))
plt.title('Trial: {}'.format(trial))
plt.savefig("./Results/reward_trial_{}_rank_{}.png".format(trial, rank), dpi = 500)

# %%
# reward vs ic
trial = 456
rank = 10

reward_list_0 = np.load('./Experiments/trial_{}_rank_{}_rewards.npy'.format(trial, rank))
# print(reward_list_0[:,0].shape)
episodes = reward_list_0[:,0].shape
reward_list_0 = reward_list_0[:,0]
reward_list_ma_0 = movingaverage(reward_list_0, 1)
plt.figure(facecolor='white')
plt.plot(reward_list_ma_0)

ic = np.load('./Experiments/trial_{}_rank_{}_episode_lru_cache_hit_ic_rate.npy'.format(trial, rank))

plt.xlabel('Episode')
plt.ylabel('Reward')
plt.ylim((0, 2.25))
# plt.ylim((0, 30))
ax2 = plt.twinx()
ax2.set_ylabel('Conformer Cache Hit Rate')
ax2.plot(ic, color='r')
ax2.tick_params(axis='y', labelcolor='r')
# plt.title('BDE Weight: 0.8, IP Weight: 0.2, Trial: {}'.format(trial))
plt.title('Trial: {}'.format(trial))
plt.savefig("./Results/reward_ic_trial_{}_rank_{}.png".format(trial, rank), dpi = 500)

# %%
trial = 88
rank = 2
reward_list_0 = np.load('./Experiments/trial_{}_rank_{}_rewards.npy'.format(trial, rank))
# print(reward_list_0[:,0].shape)
episodes = reward_list_0[:,0].shape
reward_list_0 = reward_list_0[:,0]
reward_list_ma_0 = movingaverage(reward_list_0, 20)
plt.figure(facecolor='white')
plt.plot(reward_list_ma_0)
with open('./Experiments/trial_{}_rank_{}_initial_reward.pickle'.format(trial, rank), 'rb') as f:
    init_reward = pickle.load(f)
with open(f'./Experiments/trial_{trial}_eps.pickle', 'rb') as f:
    eps = pickle.load(f)
    print(eps)

init_l = plt.axhline(init_reward[0], color='orange')
plt.legend(handles=[init_l],labels=['Initial Reward'],loc='best')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.ylim((0, 2.25))
epsilon_list = float(eps['eps_decay'])**(np.arange(len(reward_list_ma_0)))
ax2 = plt.twinx()
ax2.set_ylabel('Epsilon')
ax2.plot(epsilon_list, color='r')
ax2.tick_params(axis='y', labelcolor='r')
# plt.title('BDE Weight: 0.8, IP Weight: 0.2, Trial: {}'.format(trial))
plt.title('Trial: {}'.format(trial))
plt.savefig("./Results/reward_trial_{}_rank_{}.png".format(trial, rank), dpi = 500)
# Out:
# {'eps_threshold': 1.0, 'eps_decay': 0.999}

# %%
# count invalid 3d conformers, general model
trial = 573
world_size = 64
batch_size = 4
count = np.zeros(250)
for rank in range(world_size):
    reward_list_0 = np.load('./Experiments/trial_{}_rank_{}_rewards.npy'.format(trial, rank))
    episodes = reward_list_0[:,0].shape
#     print(episodes[0])
    for b in range(batch_size):        
        reward_list = reward_list_0[:,b]
        for i in range(episodes[0]):
            if reward_list[i] < 0:
                count[i] += 1
count = movingaverage(count, 5)

# print(count)
plt.plot(count)
plt.xlabel('Episode')
plt.ylabel('Invalid 3D conformers')

plt.title('Counts of Invalid 3D conformers in General Model')
plt.savefig("./Results/Counts_Invalid_3D_conformers_{}.png".format(trial), dpi = 500)

# %%
# count invalid 3d conformers, individual model
trial = 600
count = np.zeros(8000)
num_mols = 256
batch_size = 1

irs = [] 
for i in range(num_mols):
    ft = '600{}'.format(i)
    path = './Experiments/trial_{}_rank_{}_rewards.npy'.format(ft, 0)
#     add_reward(irs, path)
    reward_list_0 = np.load(path)
    episodes = reward_list_0[:,0].shape
#     print(episodes[0])
    for b in range(batch_size):        
        reward_list = reward_list_0[:,b]
        for i in range(episodes[0]):
            if reward_list[i] < 0:
                count[i] += 1
# print("irs:")
# print(np.average(irs))

count = movingaverage(count, 20)
     
# print(count)
plt.plot(count)
plt.xlabel('Episode')
plt.ylabel('Invalid 3D conformers')

plt.title('Counts of Invalid 3D conformers in Individual Models')
plt.savefig("./Results/Counts_Invalid_3D_conformers_{}.png".format(trial), dpi = 500)

# %%
# count invalid 3d conformers, parallel model
trial = 800
count = np.zeros(8000)
num_mols = 256
batch_size = 1

irs = [] 

for i in np.arange(0, 256, 8):
    ft = '800{}'.format(i)
    for r in range(8):
        path = './Experiments/trial_{}_rank_{}_rewards.npy'.format(ft, r)
        reward_list_0 = np.load(path)
        episodes = reward_list_0[:,0].shape
        for b in range(batch_size):        
            reward_list = reward_list_0[:,b]
            for i in range(episodes[0]):
                if reward_list[i] < 0:
                    count[i] += 1

count = movingaverage(count, 20)
     
# print(count)
plt.plot(count)
plt.xlabel('Episode')
plt.ylabel('Invalid 3D conformers')

plt.title('Counts of Invalid 3D conformers in Parallel Models')
plt.savefig("./Results/Counts_Invalid_3D_conformers_{}.png".format(trial), dpi = 500)

# %%
# count invalid 3d conformers, general model
trial = 573
world_size = 64
batch_size = 4
count_g = np.zeros(250)
for rank in range(world_size):
    reward_list_0 = np.load('./Experiments/trial_{}_rank_{}_rewards.npy'.format(trial, rank))
    episodes = reward_list_0[:,0].shape
#     print(episodes[0])
    for b in range(batch_size):        
        reward_list = reward_list_0[:,b]
        for i in range(episodes[0]):
            if reward_list[i] < 0:
                count_g[i] += 1
count_g = movingaverage(count_g, 5)

trial = 600
count_i = np.zeros(8000)
num_mols = 256
batch_size = 1

irs = [] 
for i in range(num_mols):
    ft = '600{}'.format(i)
    path = './Experiments/trial_{}_rank_{}_rewards.npy'.format(ft, 0)
#     add_reward(irs, path)
    reward_list_0 = np.load(path)
    episodes = reward_list_0[:,0].shape
#     print(episodes[0])
    for b in range(batch_size):        
        reward_list = reward_list_0[:,b]
        for i in range(episodes[0]):
            if reward_list[i] < 0:
                count_i[i] += 1
count_i = movingaverage(count_i, 20)

trial = 800
count_p = np.zeros(8000)
num_mols = 256
batch_size = 1

irs = [] 

for i in np.arange(0, 256, 8):
    ft = '800{}'.format(i)
    for r in range(8):
        path = './Experiments/trial_{}_rank_{}_rewards.npy'.format(ft, r)
        reward_list_0 = np.load(path)
        episodes = reward_list_0[:,0].shape
        for b in range(batch_size):        
            reward_list = reward_list_0[:,b]
            for i in range(episodes[0]):
                if reward_list[i] < 0:
                    count_p[i] += 1

count_p = movingaverage(count_p, 20)

print(len(count_g))
print(len(count_i))
print(len(count_p))


fig, ax1 = plt.subplots()
g = ax1.plot(count_g, color = 'blue')
plt.xlabel('Episode')

ax2 = ax1.twiny()
i = ax2.plot(count_i, color = 'red')
p = ax2.plot(count_p, color = 'orange')
fig.tight_layout()


plt.ylabel('Invalid 3D conformers')

plt.title('Counts of Invalid 3D Conformers during Training')
# plt.legend(handles=[i, p, g],labels=['Inidividual Models', 'Parallel Models', 'General Model'],loc='best')
lns = i + p + g
ax1.legend(lns, [r"MolDQN$^+$", 'MT-MolDQN$^+$', 'DA-MolDQN'],loc='best')
plt.show()

fig.savefig("./Results/Counts_Invalid_3D_conformers_All.png".format(trial), dpi = 500, bbox_inches = 'tight')
# Out:
# 246
# 7981
# 7981

# %%
# memory leak
texts = None
ranks = range(16)

# trials = [55, 56, 57, 58, 59]
# trials = [58, 59, 60, 61, 62, 63, 64]
# trials = [58, 63, 64, 65, 66, 67]
# trials = [58, 63, 67, 68, 70]
# trials = [78, 79, 80]

trials = [86, 87]
texts = [': List', ': Numpy Array']

# trials = [89, 90] # gloo vs nccl
# texts = [': gloo', ': nccl']

if texts is None:
    texts = ['' for t in trials]

def load_memory(trial, ranks):
    memory = [np.load('./Experiments/trial_{}_rank_{}_memory.npy'.format(trial, rank)) for rank in ranks]
    for mi in memory[1:]:
        memory[0] += mi
    memory = memory[0] / (1024 * 1024 * 1024)
    return memory

memorys = [load_memory(trial, ranks) for trial in trials]

fig, ax = plt.subplots()
ps = []
for m, t, tt in zip(memorys, trials, texts):
    p, = ax.plot(m, label=f"{t}{tt}")
    ps.append(p)
# print(ps)
ax.set_xlabel("Episode")
ax.set_ylabel("Memory Usage (GB)")

tkw = dict(size=4, width=1.5)
ax.tick_params(axis='y', colors=p1.get_color(), **tkw)
ax.tick_params(axis='x', **tkw)
lgd = plt.legend(handles=ps, loc='best')
plt.title('Memory Usage')
plt.savefig("./Results/trial_{}_{}_Memory.png".format(trials[0], trials[-1]), dpi = 500, bbox_extra_artists=(lgd, ))
plt.show()

# %%
trial = 6000
rank = 0
with open('./Experiments/trial_{}_rank_{}_init_mols.pickle'.format(trial, rank), 'rb') as f:
    init_mols = pickle.load(f)
    print(init_mols)
trial = 74
with open('./Experiments/trial_{}_rank_{}_init_mols.pickle'.format(trial, rank), 'rb') as f:
    init_mols = pickle.load(f)
    print(init_mols)
# Out:
# ['COc1cnc(OC)c(O)c1']
# ['COc1cnc(OC)c(O)c1']

# %%
# cenv memory leak
mf = np.load('./log/cenv_test_memory_f.npy')
mf = mf / (1024 * 1024 * 1024)

mt = np.load('./log/cenv_test_memory.npy')
mt = mt / (1024 * 1024 * 1024)

mfp = np.load('./log/cenv_test_memory_fp.npy') # 8m19
mfp = mfp / (1024 * 1024 * 1024)

fig, ax = plt.subplots()
pf, = ax.plot(mf, label="No FP")
pt, = ax.plot(mt, label="C++ Incremental FP")
pfp, = ax.plot(mfp, label="RDKit FP")

ax.set_xlabel("Episode")
ax.set_ylabel("Memory Usage (GB)")

tkw = dict(size=4, width=1.5)
ax.tick_params(axis='y', colors=p1.get_color(), **tkw)
ax.tick_params(axis='x', **tkw)
lgd = plt.legend(handles=[pf, pt, pfp], loc='best')
plt.title('Memory usage')
plt.savefig("./Results/cenv_Memory.png", dpi = 500, bbox_extra_artists=(lgd, ))
plt.show()

# %%
# relative episode time, cache hit rate
